# %%
import cv2
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Let's read the images into memory
M_image = cv2.imread("Front image/Mom_front.jpg")
S_image = cv2.imread("Front image/Jenny_front.jpg")
L_image = cv2.imread("("Trial images resize/Mom_saree.jpg")
# background = cv2.imread("images/cardnone.png")
                     
 def averagemeasure(image):
    return np.mean(image, axis=(0, 1))    

      # Store the features (average color) and corresponding label (red/green/black/none) for classification
trainX = []
trainY = []

# loop through the cards and print the average color
for (card,label) in zip((S_image,M_image,L_image,background),("S","M","L","none")):
    print((label, averagecolor(card)))
    trainX.append(averagecolor(card))
    trainY.append(label)
